# %%
# Data frame
# loading a dataframe
import pandas as pd

df = pd.read_csv("iris.csv",index_col=0)

df.head()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 7.0 KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
# first five rows?
df.head
# Out:
# <bound method NDFrame.head of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
df.head(150)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.tail(15)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# ...

# %%
df.head(190)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df[df['sepal length (cm)'] > 7]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 102                7.1               3.0                5.9               2.1
# 105                7.6               3.0                6.6               2.1
# 107                7.3               2.9                6.3               1.8
# 109                7.2               3.6                6.1               2.5
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 125                7.2               3.2                6.0               1.8
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# ...

# %%
df.loc[
    
    
    df['sepal length (cm)'] > 7,
    ['sepal length (cm)', 'target']
    
    
]
# Out:
#      sepal length (cm)  target
# 102                7.1       2
# 105                7.6       2
# 107                7.3       2
# 109                7.2       2
# 117                7.7       2
# 118                7.7       2
# 122                7.7       2
# 125                7.2       2
# 129                7.2       2
# 130                7.4       2
# 131                7.9       2
# 135                7.7       2

# %%
df['petal length squared'] = df['petal length (cm)'] **2


df.head
# Out:
# <bound method NDFrame.head of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
df.head(15)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# ...

# %%
change_df = pd.read_csv("iris.csv",index_col=0)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  petal length squared
# 0       0                  1.96
# 1       0                  1.96
# 2       0                  1.69
# 3       0                  2.25
# 4       0                  1.96

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target  petal length squared
# count        150.000000  150.000000            150.000000
# mean           1.199333    1.000000             17.218067
# std            0.762238    0.819232             12.627044
# min            0.100000    0.000000              1.000000
# 25%            0.300000    0.000000              2.560000
# ...

# %%
# Measures of correlation
# -Correlation
# -coveriance-measure whether two variables move together

# %%
import numpy as np


rng = np.random.default_rng(42) #seed 

n = 25

study_hours = rng.uniform(1, 10, n).round(1)

#exam_score
exam_score = (40 + study_hours + 5 + rng.normal(0, 8, n)).round(1)
exam_score = np.clip(exam_score, 0, 100)

age = rng.integers(18, 45, n)


class_df = pd.DataFrame({
    'study hours':study_hours,
    'exam_score':exam_score,
    'age':age}
)

class_df.head()
# Out:
#    study hours  exam_score  age
# 0          8.0        50.2   39
# 1          4.9        54.2   39
# 2          8.7        56.6   39
# 3          7.3        55.6   35
# 4          1.8        50.2   30

# %%
cov_matrix =class_df[['study hours','exam_score']].cov()

cov_matrix
# Out:
#              study hours  exam_score
# study hours     6.364167    7.096500
# exam_score      7.096500   38.504433

# %%
corr_study_score =class_df['study hours'].corr(class_df['exam_score'])

print(corr_study_score)
# Out:
# 0.4533337644677941

# %%
# -pearson correlation coefficient(r)

corr_age_score = class_df['study hours'].corr(class_df['age'])

print(corr_age_score)
# Out:
# 0.11942807298651517

# %%
class_df.corr()
# Out:
#              study hours  exam_score       age
# study hours     1.000000    0.453334  0.119428
# exam_score      0.453334    1.000000  0.211597
# age             0.119428    0.211597  1.000000

# %% [markdown]
# ###Data Visualizations with Python
#
# # Matplotlib
# Is a library in python that is used to create a static visualizations
# # Seaborn
#
# Is a library built on top of Matplotlib to make it easier to create visualizations

# %%
import matplotlib.pyplot as plt


#scatter plot
plt.figure(figsize=(4,2))

plt.scatter(class_df['study hours'], class_df['exam_score'])
plt.title('Study hours vs Exam Score')
plt.xlabel('study_hours')
plt.ylabel('exam score')
plt.show()

# %%
#histogram
plt.figure(figsize=(4, 2))

plt.hist(class_df['exam_score'], bins=8 , edgecolor= "black")
plt.title('Distribution of Exam Score')
plt.xlabel('Exam Score')
plt.ylabel('Number of students')
plt.show()

# %%
## correlation matrix

import seaborn as sns

plt.figure(figsize=(6, 4))

sns.heatmap(class_df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)

plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6, 4))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)

plt.title('Correlation Heatmap')
plt.show()

# %%
# import numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt 

# Set seed for reproducability
np.random.seed(100)

# Generate a data set of 200 retirement age values
x = 5*np.random.randn(200) + 65

plt.hist(x , bins = 10, edgecolor ='black')
plt.xlabel('Retirement Age')
plt.ylabel('Frequency of Values')
plt.title('Histograms of Matplotlib')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(x, bins=5 ,edgecolor = 'green')
plt.xlabel('Salary Expectation')
plt.ylabel("Retirement age")
plt.title("Salary Expection vs Retirement age")
plt.show()

# %%
# Set seed for reproducability 
np.random.seed(100) 
# Generate retirement age and life expectancy data 
retirement_age = 5 * np.random.randn(200) + 65 
life_expectancy = np.random.randint(75, 101, size=200) 

# Plot the scatter plot 
plt.scatter(retirement_age, life_expectancy, c='blue', alpha=0.7) # c is color alpha is transparency 

# Add labels 
plt.xlabel('Retirement Age') 
plt.ylabel('Life Expectancy') 
plt.title('Relationship Between Retirement Age and Life Expectancy (Simulated Data)')
plt.show()

# %% [markdown]
# ##Introduction to probability Distribution
#
# Discrete random variable take on a countable set of values i.e think number of heads in the coin flips
# .We use 'Probabilty Mass Function(PMF).This gives  you exact probability of each specific value.
#
# Continous Random variables can take any value within a range i.e tempearture,height,time.For for this one ,you can't all possible values thus use a 'Probability Density Function'(PDF)

# %%
import numpy as np

import matplotlib.pyplot as plt

import pandas as pd

import seaborn as sns


rng =np.random.default_rng(42)

uniform_samples = rng.uniform(0 ,1 ,1000)

plt.figure(figsize =(6,4))

plt.hist(uniform_samples, bins=10, edgecolor ='black', color ='green')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Uniform samples')
plt.show()

# %%
#normal distribution of heights

mean, std = 170, 10
normal_samples = rng.normal(loc=mean, scale=std, size=10000)

plt.figure(figsize=(6, 4))
plt.hist(normal_samples, bins=30, edgecolor='black', color='blue', density=True, alpha=0.7, label='Normal Sample')

#pdf
x = np.linspace(normal_samples.min(), normal_samples.max(), 199)
plt.plot(x, scipy.stats.norm.pdf(x, loc=mean, scale=std), color='orange', label='sample pdf')

plt.title('Normal Distribution mean = 170, std=10')
plt.xlabel('Heights(cm)')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 11
#       9 #pdf
#      10 x = np.linspace(normal_samples.min(), normal_samples.max(), 199)
# ---> 11 plt.plot(x, scipy.stats.norm.pdf(x, loc=mean, scale=std), color='orange', label='sample pdf')
#      13 plt.title('Normal Distribution mean = 170, std=10')
#      14 plt.xlabel('Heights(cm)')
#
# NameError: name 'scipy' is not defined

# %%
binomial_samples = rng.binomial(n=20, p=0.5, size=10000)

plt.figure(figsize=(6, 4))
plt.hist(binomial_samples, bins=range(0, 22), edgecolor="black", color="mediumseagreen", align="left")
plt.title("Binomial Distribution (n=20 flips, p=0.5)")
plt.xlabel("Number of Heads")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##Introduction to object-Oriented Programming

# %%
class Student:
    def __init__(self, first_name, last_name, subject):
        self.first_name = first_name
        self.last_name = last_name
        self.subject = subject

    def capitalize(self):
        fullname = self.first_name + " " + self.last_name
        return fullname.upper()
    
    
    def welcome(self):
        sentence = f"Dear {self.first_name.title()} welcome to Moringa School and the {self.subject.lower()} course"
        return sentence
    
    
        
    

student_1 = Student('bunei', 'shadrack', 'data science')

student_1.capitalize()
print(student_1.welcome())
# Out:
# Dear Bunei welcome to Moringa School and the data science course

# %%
student_2 = Student('JAcoB', 'Tai', 'Software Development')
student_3 = Student('rAcheL', 'WanjIku', 'CyberSecurity')
student_4 = Student('Mercy', 'Korir', 'DevOps')



student_4.capitalize()
# Out:
# 'MERCY KORIR'

# %%
new_students = [
    
    
    student_1,
    student_2,
    student_3,
    student_4
       
]

for new_student in new_students:
    print(new_student.welcome())
# Out:
# Dear Bunei welcome to Moringa School and the data science course
# Dear Jacob welcome to Moringa School and the software development course
# Dear Rachel welcome to Moringa School and the cybersecurity course
# Dear Mercy welcome to Moringa School and the devops course

# %% [markdown]
# ###Introduction to Databases and SQL
# types
#
# SQL(Strutured query language)
#
# Relational databases
# Non-relational Databases
#
#
# Types of Relational Databases:
# SQL lite
# MySQL
# Postgress SQL
# Oracle
# SQL server
#
#
# Types of Non-Relational Databases:
#
# MOngoDB
# Redies
# Kasanta
#
#
# DDL-Data Definition language(Creating,altering and dropping)
# DML-Data manapulation Language(for Data Manupulation)
# DCL-Data Control Language
# TCL-Transaction Control Language

# %%
    """
    
    SELECT *  
    
    FROM iris;
    """
# Out:
# '\n\nSELECT *  \n\nFROM iris;\n'

# %%
import sqlite3

# %% [markdown]
# Introductions to Pandas

# %%
import pandas as pd

pd.Series([25000,0,4500,2,8],
          
          index =['Muammar Qaddafi','Mohandas Gandhi','Saddam Hussein','Kevin Bacon','Billy Bob Thornton'],
          name ='Max Number Cars Owned' 
          )
# Out:
# Muammar Qaddafi       25000
# Mohandas Gandhi           0
# Saddam Hussein         4500
# Kevin Bacon               2
# Billy Bob Thornton        8
# Name: Max Number Cars Owned, dtype: int64

# %%
car_dict ={'Muammar Qaddafi':25000,'Mohandas Gandhi':0,'Saddam Hussein':4500,'Kevin Bacon':2,'Billy Bob Thornton':8}

car_owner_series = pd.Series(car_dict, name = 'Max Cars Owned')

car_owner_series

car_dict

car_owner_series['Muammar Qaddafi'
                 :'Mohandas Gandhi']


car_owner_series['Mohandas Gandhi':'Kevin Bacon']
# Out:
# Mohandas Gandhi       0
# Saddam Hussein     4500
# Kevin Bacon           2
# Name: Max Cars Owned, dtype: int64

# %%
delta_cars ={'Mohandas Gandhi':0,'Billy Bob Thornton':2,'Saddam Hussein':0,'Kevin Bacon':1,'Muammar Qaddafi':0}
delta_cars_series =pd.Series(delta_cars,name ='Max Number Owned')

delta_cars_series
# Out:
# Mohandas Gandhi       0
# Billy Bob Thornton    2
# Saddam Hussein        0
# Kevin Bacon           1
# Muammar Qaddafi       0
# Name: Max Number Owned, dtype: int64

# %%
car_owner_series
# Out:
# Muammar Qaddafi       25000
# Mohandas Gandhi           0
# Saddam Hussein         4500
# Kevin Bacon               2
# Billy Bob Thornton        8
# Name: Max Cars Owned, dtype: int64

# %%
new_car_series =car_owner_series + delta_cars_series


new_car_series
# Out:
# Billy Bob Thornton       10
# Kevin Bacon               3
# Mohandas Gandhi           0
# Muammar Qaddafi       25000
# Saddam Hussein         4500
# dtype: int64

# %%
new_car_series.index
# Out:
# Index(['Billy Bob Thornton', 'Kevin Bacon', 'Mohandas Gandhi',
#        'Muammar Qaddafi', 'Saddam Hussein'],
#       dtype='object')

# %%
new_car_series.values
# Out:
# array([   10,     3,     0, 25000,  4500])

# %%
new_car_series.name

# %%
new_car_series.sort_values(ascending =False)
# Out:
# Muammar Qaddafi       25000
# Saddam Hussein         4500
# Billy Bob Thornton       10
# Kevin Bacon               3
# Mohandas Gandhi           0
# dtype: int64

# %%
iris_df = pd.read_csv('iris.csv',index_col = 0)

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris_df.head(5)
# Out:
#                    Unnamed: 0  sepal width (cm)  petal length (cm)  \
# sepal length (cm)
# 5.1                         0               3.5                1.4
# 4.9                         1               3.0                1.4
# 4.7                         2               3.2                1.3
# 4.6                         3               3.1                1.5
# 5.0                         4               3.6                1.4
#
#                    petal width (cm)  target
# sepal length (cm)
# 5.1                             0.2       0
# 4.9                             0.2       0
# 4.7                             0.2       0
# 4.6                             0.2       0
# 5.0                             0.2       0

# %%
iris_df.tail
# Out:
# <bound method NDFrame.tail of                    Unnamed: 0  sepal width (cm)  petal length (cm)  \
# sepal length (cm)
# 5.1                         0               3.5                1.4
# 4.9                         1               3.0                1.4
# 4.7                         2               3.2                1.3
# 4.6                         3               3.1                1.5
# 5.0                         4               3.6                1.4
# ...                       ...               ...                ...
# 6.7                       145               3.0                5.2
# 6.3                       146               2.5                5.0
# 6.5                       147               3.0                5.2
# 6.2                       148               3.4                5.4
# 5.9                       149               3.0                5.1
#
#                    petal width (cm)  target
# sepal length (cm)
# 5.1                             0.2       0
# ...

# %%
iris_df.info
# Out:
# <bound method DataFrame.info of                    Unnamed: 0  sepal width (cm)  petal length (cm)  \
# sepal length (cm)
# 5.1                         0               3.5                1.4
# 4.9                         1               3.0                1.4
# 4.7                         2               3.2                1.3
# 4.6                         3               3.1                1.5
# 5.0                         4               3.6                1.4
# ...                       ...               ...                ...
# 6.7                       145               3.0                5.2
# 6.3                       146               2.5                5.0
# 6.5                       147               3.0                5.2
# 6.2                       148               3.4                5.4
# 5.9                       149               3.0                5.1
#
#                    petal width (cm)  target
# sepal length (cm)
# 5.1                             0.2       0
# ...

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 5.1 to 5.9
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         150 non-null    int64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 7.0 KB

# %%
iris_df.describe()
# Out:
#        Unnamed: 0  sepal width (cm)  petal length (cm)  petal width (cm)  \
# count  150.000000        150.000000         150.000000        150.000000
# mean    74.500000          3.057333           3.758000          1.199333
# std     43.445368          0.435866           1.765298          0.762238
# min      0.000000          2.000000           1.000000          0.100000
# 25%     37.250000          2.800000           1.600000          0.300000
# 50%     74.500000          3.000000           4.350000          1.300000
# 75%    111.750000          3.300000           5.100000          1.800000
# max    149.000000          4.400000           6.900000          2.500000
#
#            target
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
iris_df.index[0:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 iris_df.index.columns
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df['target']
# Out:
# sepal length (cm)
# 5.1    0
# 4.9    0
# 4.7    0
# 4.6    0
# 5.0    0
#       ..
# 6.7    2
# 6.3    2
# 6.5    2
# 6.2    2
# 5.9    2
# Name: target, Length: 150, dtype: int64

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris_df.iloc['target']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 iris_df.iloc['target']
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1750, in _iLocIndexer._getitem_axis(self, key, axis)
#    1748 key = item_from_zerodim(key)
#    1749 if not is_integer(key):
# -> 1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
#    1753 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
iris_df = iris_df.rename(columns ={'sepal length (cm)':'Shadrack'})
iris_df.head(2)
# Out:
#                    Unnamed: 0  sepal width (cm)  petal length (cm)  \
# sepal length (cm)
# 5.1                         0               3.5                1.4
# 4.9                         1               3.0                1.4
#
#                    petal width (cm)  target
# sepal length (cm)
# 5.1                             0.2       0
# 4.9                             0.2       0

# %%
iris_df['target']
# Out:
# sepal length (cm)
# 5.1    0
# 4.9    0
# 4.7    0
# 4.6    0
# 5.0    0
#       ..
# 6.7    2
# 6.3    2
# 6.5    2
# 6.2    2
# 5.9    2
# Name: target, Length: 150, dtype: int64

# %%
iris_df = iris_df.rename(columns ={'target':'Shadrack'})
iris_df.head(2)
# Out:
#                    Unnamed: 0  sepal width (cm)  petal length (cm)  \
# sepal length (cm)
# 5.1                         0               3.5                1.4
# 4.9                         1               3.0                1.4
#
#                    petal width (cm)  Shadrack
# sepal length (cm)
# 5.1                             0.2         0
# 4.9                             0.2         0

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Shadrack'],
#       dtype='object')

# %%
iris_df['Shadrack']
# Out:
# sepal length (cm)
# 5.1    0
# 4.9    0
# 4.7    0
# 4.6    0
# 5.0    0
#       ..
# 6.7    2
# 6.3    2
# 6.5    2
# 6.2    2
# 5.9    2
# Name: Shadrack, Length: 150, dtype: int64

# %%
[col.strip() for col in iris_df.columns]
# Out:
# ['Unnamed: 0',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)',
#  'Shadrack']

# %%
iris_df.drop(columns =['petal length (cm)'] , inplace =True)
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'sepal width (cm)', 'petal width (cm)', 'Shadrack'], dtype='object')

# %%
iris_df['petal width (cm)']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal width (cm), Length: 150, dtype: float64

# %%
iris_df['petal width (cm)'].median(
    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 iris_df['petal width (cm)'].median(
#       2
#       3 )
#
# NameError: name 'iris_df' is not defined

# %%
import pandas as pd

# Sample DataFrame with NaNs
data = {'Age': [25, 25, 30], 'City': ['Boston', 'New York', 'Chicago'], 'Salary': [None, 139000, None]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Age      City    Salary
# 0   25    Boston       NaN
# 1   25  New York  139000.0
# 2   30   Chicago       NaN

# %%
missing_val_mask =df.isna()

print(missing_val_mask)



missing_val_mask = df.isna().sum()
print(missing_val_mask)
# Out:
#      Age   City  Salary
# 0  False  False    True
# 1   True  False   False
# 2  False  False    True
# Age       1
# City      0
# Salary    2
# dtype: int64

# %%
dropped_raw_df =missing_val_mask.dropna()

print(dropped_raw_df)

print (missing_val_mask)


dfm =df['Age'].isna()
# Out:
# Age       1
# City      0
# Salary    2
# dtype: int64
# Age       1
# City      0
# Salary    2
# dtype: int64

# %%
dfm =df['Age'].isna()

print(dfm)
# Out:
# 0    False
# 1     True
# 2    False
# Name: Age, dtype: bool

# %%
dfmn =df['Age'].notna()

print(dfmn)
# Out:
# 0     True
# 1    False
# 2     True
# Name: Age, dtype: bool

# %%
import numpy as np

dfmw =df['Age'].replace(to_replace =9999),
value =np.nan

print(dfmw)
# Out:
# (0    25.0
# 1     NaN
# 2    30.0
# Name: Age, dtype: float64,)
# /var/folders/n2/tf6v9x0d6cj5fjycq18txws80000gn/T/ipykernel_6895/712094306.py:3: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   dfmw =df['Age'].replace(to_replace =9999),

# %%
print(df)

dfq= df.dropna()

print(dfq)
# Out:
#     Age      City    Salary
# 0  25.0    Boston       NaN
# 1   NaN  New York  139000.0
# 2  30.0   Chicago       NaN
# Empty DataFrame
# Columns: [Age, City, Salary]
# Index: []

# %%
dfm =df.duplicated()
print(dfm)
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Users/shadrack/Flatiron/Austin_Animal_Center_Outcomes_(10_01_2013_to_05_05_2025)_20260717.csv')

# %%
df.head()
# Out:
#   Animal ID Date of Birth Name                   DateTime MonthYear  \
# 0   A668305    2012-12-01  NaN  2013-12-02T00:00:00-05:00   12-2013
# 1   A673335    2012-02-22  NaN  2014-02-22T00:00:00-05:00   02-2014
# 2   A675999    2013-04-03  NaN  2014-04-07T00:00:00-05:00   04-2014
# 3   A679066    2014-04-16  NaN  2014-05-16T00:00:00-05:00   05-2014
# 4   A680855    2014-05-25  NaN  2014-06-10T00:00:00-05:00   06-2014
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0     Transfer         Partner       Other          Unknown           1 year
# 1   Euthanasia       Suffering       Other          Unknown          2 years
# 2     Transfer         Partner       Other          Unknown           1 year
# 3          NaN             NaN       Other          Unknown          4 weeks
# 4     Transfer         Partner        Bird          Unknown          2 weeks
#
#         Breed         Color
# 0  Turtle Mix  Brown/Yellow
# 1     Raccoon    Black/Gray
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173775 entries, 0 to 173774
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         173775 non-null  object
#  1   Date of Birth     173775 non-null  object
#  2   Name              123991 non-null  object
#  3   DateTime          173775 non-null  object
#  4   MonthYear         173775 non-null  object
#  5   Outcome Type      173729 non-null  object
#  6   Outcome Subtype   79660 non-null   object
#  7   Animal Type       173775 non-null  object
#  8   Sex upon Outcome  173774 non-null  object
#  9   Age upon Outcome  173766 non-null  object
#  10  Breed             173775 non-null  object
#  11  Color             173775 non-null  object
# dtypes: object(12)
# memory usage: 15.9+ MB

# %%
df["DateTime"] = pd.to_datetime(df["DateTime"], errors="coerce")

# %%
df["Date of Birth"] = pd.to_datetime(df["Date of Birth"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173775 entries, 0 to 173774
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         173775 non-null  object
#  1   Date of Birth     173775 non-null  datetime64[ns]
#  2   Name              123991 non-null  object
#  3   DateTime          3584 non-null    datetime64[ns, UTC-05:00]
#  4   MonthYear         173775 non-null  object
#  5   Outcome Type      173729 non-null  object
#  6   Outcome Subtype   79660 non-null   object
#  7   Animal Type       173775 non-null  object
#  8   Sex upon Outcome  173774 non-null  object
#  9   Age upon Outcome  173766 non-null  object
#  10  Breed             173775 non-null  object
#  11  Color             173775 non-null  object
# dtypes: datetime64[ns, UTC-05:00](1), datetime64[ns](1), object(10)
# memory usage: 15.9+ MB

# %%
df.columns
# Out:
# Index(['Animal ID', 'Date of Birth', 'Name', 'DateTime', 'MonthYear',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %%
df.drop(columns =['Outcome Subtype'],inplace = True)

df.columns
# Out:
# Index(['Animal ID', 'Date of Birth', 'Name', 'DateTime', 'MonthYear',
#        'Outcome Type', 'Animal Type', 'Sex upon Outcome', 'Age upon Outcome',
#        'Breed', 'Color'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
#        Animal ID Date of Birth          Name                  DateTime  \
# 1704     A755088    2016-09-29       Machete 2017-08-19 00:00:00-05:00
# 2913     A664097    2012-12-29         Remmy                       NaT
# 3072     A663004    2013-01-14        *Allie                       NaT
# 3168     A663168    2012-03-13        Archer                       NaT
# 3233     A641748    2008-11-12         Champ                       NaT
# ...          ...           ...           ...                       ...
# 173524   A922150    2025-02-07  *King Scooby                       NaT
# 173535   A925662    2023-02-27         Diego                       NaT
# 173596   A928715    2023-04-18       Stryker                       NaT
# 173614   A928219    2020-04-09  Dilly Doodle                       NaT
# 173627   A928093    2024-11-07         *John                       NaT
#
#        MonthYear     Outcome Type Animal Type Sex upon Outcome  \
# ...

# %%
df.drop_duplicates(inplace=True)

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Age upon Outcome'].isna().sum())
print(df['Age upon Outcome'].dtype)
print(df['Age upon Outcome'].head())
# Out:
# 9
# object
# 0     1 year
# 1    2 years
# 2     1 year
# 3    4 weeks
# 4    2 weeks
# Name: Age upon Outcome, dtype: object

# %%
df.columns
# Out:
# Index(['Animal ID', 'Date of Birth', 'Name', 'DateTime', 'MonthYear',
#        'Outcome Type', 'Animal Type', 'Sex upon Outcome', 'Age upon Outcome',
#        'Breed', 'Color'],
#       dtype='object')

# %%
print(df['Age upon Outcome'].dtype)
# Out:
# object

# %%
df.isna().sum()
# Out:
# Animal ID                0
# Date of Birth            0
# Name                 49663
# DateTime            168301
# MonthYear                0
# Outcome Type            46
# Animal Type              0
# Sex upon Outcome         1
# Age upon Outcome         9
# Breed                    0
# Color                    0
# dtype: int64

# %%
class Student:
    def __init__(self,name,student_id,major,year_of_study,courses):
        self.name = name
        self.student_id = student_id
        self.major = major
        self.year_of_study =year_of_study
        self.courses = {}
        
    
    
    
    
    
    def display_info(self):
        print('Student Information')
        print('Name :' , self.name)
        print('Student ID :' ,self.student_id)
        print('Major' ,self.major)
        print('Year of Study' , self.year_of_study)
        print('Enrolled Courses', self.courses)
        
    def add_course(self,course,grade):
        self.courses[course] = grade
        print (f"added course: {course}")
        
    def remove_course(self,course):
        if course in self.courses.keys():
            del self.courses[course]
            print(f"Removed course : {course}")
        else:
            
            print(f"Course {course} not found.")
            
    def calculate_gpa(self):
        total_grade_points= sum(self.courses.values())
        total_credits = len(self.courses)
        gpa = total_grade_points / total_credits
        
        return round(gpa, 2)
    
    def academic_standing(self,gpa):
        
        if gpa >= 3.0:
            return "Good Standing"
        elif gpa >= 2.0:
            return "Satisfactory"
        else:
            return "Academic Probation"
student1 =Student("Bunei Shadrack",'S001','Computer Science',3,'Sophomore')
student2 =Student("Wesly Peter",'S002','data Science',2,'Analysis')

student1.display_info()
# Out:
# Student Information
# Name : Bunei Shadrack
# Student ID : S001
# Major Computer Science
# Year of Study 3
# Enrolled Courses {}

# %%
student1.add_course('Data Science',3.5)
# Out:
# added course: Data Science

# %%
student1.remove_course('Data Science')
# Out:
# Removed course : Data Science

# %%
student1.display_info()
# Out:
# Student Information
# Name : Bunei Shadrack
# Student ID : S001
# Major Computer Science
# Year of Study Sophomore
# Enrolled Courses {'Data Science': 3.5, 'information Data': 2.5}

# %%
student1.add_course('information Data',2.5)
# Out:
# added course: information Data

# %%
gpa1 = student1.calculate_gpa()
print(f"GPA for {student1.name}: {gpa1}")
# print(f"Academic Standing for {student1.name}: {student1.academic_standing(gpa1)}")
# print()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 gpa1 = student1.calculate_gpa()
#       2 print(f"GPA for {student1.name}: {gpa1}")
#       3 # print(f"Academic Standing for {student1.name}: {student1.academic_standing(gpa1)}")
#       4 # print()
#
# Cell In[25], line 37, in Student.calculate_gpa(self)
#      35 total_grade_points= sum(self.courses.values())
#      36 total_credits = len(self.courses)
# ---> 37 gpa = total_grade_points / total_credits
#      39 return round(gpa, 2)
#
# ZeroDivisionError: division by zero

# %%
student2.add_course("Financial Accounting", 3.2)
student2.add_course("Marketing", 2.8)
student2.display_info()
# Out:
# added course: Financial Accounting
# added course: Marketing
# Student Information
# Name : Wesly Peter
# Student ID : S002
# Major data Science
# Year of Study 2
# Enrolled Courses {'Financial Accounting': 3.2, 'Marketing': 2.8}

# %%
gpa2 = student2.calculate_gpa()
print(f"GPA for {student2.name}: {gpa2}")
print(f"Academic Standing for {student2.name}: {student2.academic_standing(gpa2)}")
# Out:
# GPA for Wesly Peter: 3.0
# Academic Standing for Wesly Peter: Good Standing

# %%
gpa1 = student1.calculate_gpa()
print(f"GPA for {student1.name}: {gpa1}")
print(f"Academic Standing for {student1.name}: {student1.academic_standing(gpa1)}")
print()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 gpa1 = student1.calculate_gpa()
#       2 print(f"GPA for {student1.name}: {gpa1}")
#       3 print(f"Academic Standing for {student1.name}: {student1.academic_standing(gpa1)}")
#
# Cell In[25], line 37, in Student.calculate_gpa(self)
#      35 total_grade_points= sum(self.courses.values())
#      36 total_credits = len(self.courses)
# ---> 37 gpa = total_grade_points / total_credits
#      39 return round(gpa, 2)
#
# ZeroDivisionError: division by zero
